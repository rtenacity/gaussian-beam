# %%
from scipy.constants import pi 
from scipy.special import factorial
import numpy as np
import matplotlib.pyplot as plt
from scipy.special import hermite
import plotly.graph_objects as go

# %%
# Free parameters, typical setup for a HeNe laser (https://sites.astro.caltech.edu/~lah/ay105/pdf/Laser-Guide.pdf, page 8)

w_0 = 0.13 * 10**-3 # Beam waist (0.13 mm)
n = 1 # Refractive index of air
wavelength = 633 * 10**-9 # 633 nanometers (red light)
E_0 = 1 + 0j # E (V/m) some arbitrary value for visualization

k = 2 * pi * n / wavelength # Wave number

# %%
z_R = pi * w_0**2 * n / wavelength # Rayleigh range

def w(z):
    return w_0 * np.sqrt(1+ np.power(z/z_R, 2))

def R(z):
    # handles both scalar and array input
    z = np.asarray(z, dtype=np.complex128)
    # avoid division by zero
    Rz = np.where(z == 0, np.inf, z * (1 + (z_R / z)**2))
    return Rz


def E(x, y, z, l, m): # Returns a complex electric field value at (x,y,z) for mode (l,m)
    # Get Hermite polynomial functions for l and m
    H_l = hermite(l) 
    H_m = hermite(m)
    N = l+m
    
    u = np.sqrt(2) * x / w(z)
    v = np.sqrt(2) * y / w(z)

    norm_factor = (1/w_0) * np.sqrt(2 / (pi * 2**(l+m) * factorial(l) * factorial(m)))

    real = E_0 * (w_0/w(z)) * H_l(u) * H_m(v) * np.exp(-(x**2 + y**2)/(w(z)**2)) * norm_factor

    radial_phase = -k *(x**2 + y**2)/(2*R(z))
    longitudal_phase = -k*z
    gouy_phase = (N + 1) * np.arctan(z/z_R)

    phase = radial_phase + longitudal_phase + gouy_phase
    
    return real * np.exp(1j * phase) # Complex electric field

# %%
def superposition(x, y, z, modes):
    E_total = 0
    for (l, m, coeff) in modes:
        E_total += coeff * E(x, y, z, l, m) # Linear superposition of modes, weighted by coeffients
    return E_total


def intensity(x, y, z, modes):
    E_total = superposition(x, y, z, modes)
    return np.abs(E_total)**2 # Intensity is proportional to the square of the electric field amplitude (modulus squared for complex E)

# %%
z = 0.5 * z_R # Observation plane at 0.5 Rayleigh ranges
x = np.linspace(-3*w_0, 3*w_0, 400)
y = np.linspace(-3*w_0, 3*w_0, 400)
X, Y = np.meshgrid(x, y)

# %%
alpha = 0.75

def calculate_coherent_coeff(l):
    return np.exp(-0.5 * alpha**2) * (alpha**l) / np.sqrt(factorial(l))


modes_coherent = [(l, 0, calculate_coherent_coeff(l)) for l in range(30)] # Coherent state along x-axis, m=0

center_pred = alpha * w(0)

# %%
I_super = intensity(X, Y, z, modes_coherent)

# Matplotlib 2D Contour Plot
plt.figure(figsize=(8, 6))
plt.contourf(X*1e3, Y*1e3, I_super, levels=100, cmap='inferno') # Convert to mm for better visualization
plt.colorbar(label='Intensity ($W/m^2$)')

# place a marker at the predicted center
plt.plot(center_pred*1e3, 0, 'bo', label='Predicted Center', markersize=8) # Convert to mm
plt.legend()
plt.title(f'Superposition of TEM Modes at z={z*1e3:.1f} mm')
plt.xlabel('x ($mm$ )')
plt.ylabel('y ($mm$)')
plt.axis('equal')
plt.show()

# %%
# 3D Surface Plot with Plotly
fig = go.Figure(data=[go.Surface(z=I_super, x=X*1e3, y=Y*1e3, colorscale='Inferno')])

# set colorbar title
fig.update_traces(colorbar_title='Intensity (W/m²)')

fig.update_layout(title=f'Superposition of TEM Modes at z={z*1e3:.1f} mm)',
                  scene = dict(
                      xaxis_title='X (mm)',
                      yaxis_title='Y (mm)',
                      zaxis_title='Intensity (W/m²)',
                      aspectratio=dict(x=1, y=1, z=0.5)),
                  width=800, height=800,
                  )  
fig.show()

# %%
def phi_z(z):
    return np.arctan(z/z_R)

def E_coherent_analytical_phase(x, y, z, alpha):
    # ensure complex arithmetic
    x = np.asarray(x, dtype=np.complex128)
    y = np.asarray(y, dtype=np.complex128)

    w_z = w(z)
    # 1D normalization factor; final 2D normalization uses its square
    A_1d = (2.0 / np.pi) ** 0.25 / np.sqrt(w_z)

    # exponent that must be inside an exponential
    prefactor_exponent = (-np.abs(alpha) ** 2 + (alpha ** 2) * np.exp(2j * phi_z(z))) / 2.0

    # complex center
    x_0 = alpha * w_z * np.exp(1j * phi_z(z))

    # Gaussian envelope with complex center
    gaussian = np.exp(-((x - x_0) ** 2 + y ** 2) / (w_z ** 2))

    # phase factors
    radial_phase = np.exp(-1j * k * (x ** 2 + y ** 2) / (2.0 * R(z)))
    longitudinal_phase = np.exp(-1j * k * z)
    gouy_phase = np.exp(1j * phi_z(z))

    # build total field
    E = (A_1d ** 2) * np.exp(prefactor_exponent) * gaussian * radial_phase * longitudinal_phase * gouy_phase

    return E

# %%
def E_coherent_analytical(x, y, z, alpha):
    A0 = np.sqrt(2.0 / np.pi) / w(z)
    
    prefactor = np.exp((alpha**2 - np.abs(alpha)**2) / 2.0)
    
    x_0 = np.real(alpha) * w(z)

    envelope = np.exp(-((x - x_0)**2 + y**2) / (w(z)**2))

    real = A0 * prefactor * envelope


    radial_phase = -k *(x**2 + y**2)/(2*R(z))
    longitudal_phase = -k*z

    phase = radial_phase + longitudal_phase
    
    return real * np.exp(1j * phase) # Complex electric field


I_analytical_phase = np.abs(E_coherent_analytical_phase(X, Y, z, alpha))**2

print(np.max(I_analytical_phase) / np.max(I_super))


#plot comparison
plt.figure(figsize=(16, 6))
plt.subplot(1, 2, 1)
plt.contourf(X*1e3, Y*1e3, I_super, levels=100, cmap='inferno')
plt.colorbar(label='Intensity ($W/m^2$)')
plt.title('Superposition of TEM Modes')
plt.xlabel('x ($mm$ )')
plt.ylabel('y ($mm$)')
plt.axis('equal')

plt.subplot(1, 2, 2)
plt.contourf(X*1e3, Y*1e3, I_analytical_phase, levels=100, cmap='inferno')
plt.colorbar(label='Intensity ($W/m^2$)')
plt.title('Analytical Coherent State')
plt.xlabel('x ($mm$ )')
plt.ylabel('y ($mm$)')
plt.axis('equal')
plt.show()
# Out:
# 0.9999999999969513

# %%
# mse between the two
np.mean((I_super - I_analytical_phase)**2)
# Out:
# np.float64(6.467909569732745e-10)

# %%
# plot value of coefficients vs mode index

num_modes = 50

coeffs = [calculate_coherent_coeff(l) for l in range(num_modes)]
plt.figure(figsize=(8, 5))
plt.scatter(range(num_modes), coeffs)
plt.yscale('log')
plt.xlabel('Mode index l')
plt.ylabel('Coefficient magnitude')
plt.title('Coefficients for Coherent State Superposition')
plt.grid()

# get last coefficient above threshold
threshold = 1e-20
last_significant_mode = max(l for l, c in enumerate(coeffs) if np.abs(c) > threshold)
print(f'Last significant mode index (|c| > {threshold}): {last_significant_mode}')
plt.axvline(last_significant_mode, color='r', linestyle='--', label='Last Significant Mode')
plt.legend()
plt.show()
# Out:
# Last significant mode index (|c| > 1e-20): 29

# %%
num_x = 200
num_z = 180

z = np.linspace(-z_R, z_R, num_z)

X, Z = np.meshgrid(x, z)

# compute intensity on the slice y=0
Y = np.zeros_like(X)
I_xz = np.abs(E_coherent_analytical_phase(X, Y, Z, alpha))**2

# convert to mm for plotting axes and scale intensity for visibility
X_mm = X * 1e3
Z_mm = Z * 1e3

# build plotly surface
fig = go.Figure(data=[go.Surface(x=X_mm, y=Z_mm, z=I_xz,
                                 colorscale='Inferno', cmin=0, cmax=np.max(I_xz))])

fig.update_layout(title='Beam propagation along z axis (slice at y=0)',
                  scene=dict(xaxis_title='x (mm)',
                             yaxis_title='z (mm)',
                             zaxis_title='Intensity (a.u.)',
                             aspectratio=dict(x=1.2, y=2.0, z=0.6)),
                  width=900, height=700)

fig.show()
